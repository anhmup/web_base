# %%
# !pip install flask
# !pip install flask-ngrok
# !pip install pyngrok

# %% [markdown]
# # html page

# %%
# prompt: check and create folder templates

import os

def check_and_create_folder(folder_path):
    """Checks if a folder exists and creates it if it doesn't."""
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
        print(f"Folder '{folder_path}' created successfully.")
    else:
        print(f"Folder '{folder_path}' already exists.")

# Example usage
check_and_create_folder("templates")
# Out:
# Folder 'templates' already exists.

# %%
html_code = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Upload and Draw Rectangles</title>

    <style>
        body { font-family: Arial, sans-serif; text-align: center; margin: 50px; }
        .button { background-color: #4169E1; color: white; border: none; padding: 10px 20px; cursor: pointer; margin-top: 10px; }
        img { margin-top: 20px; border: 2px solid black; }
    </style>

    <script>
        function uploadAndShowImage() {
            const fileInput = document.getElementById('fileInput');
            fileInput.click();
            fileInput.onchange = function() {
                if (fileInput.files.length > 0) {
                    document.getElementById('uploadForm').submit();
                }
            };
        }
    </script>
</head>
<body>
    <h1>Table Detection & Structure Recognition NGUYEN QUOC ANH</h1>
    <p>Upload an image containing a table to detect its structure.</p>

    <div class="upload-box">
        <form id="uploadForm" action="/" method="post" enctype="multipart/form-data">
            <input type="file" id="fileInput" name="file" accept="image/*" required style="display: none;">
            <button type="button" class="button" onclick="uploadAndShowImage();">Upload and Display Image</button>
        </form>
    </div>

    {% if filename %}
    <div class="image-container">
        <h2>Original Image</h2>
        <img src="{{ url_for('static', filename='uploads/' + filename) }}" alt="Uploaded Image" width="300">

        <form action="/draw" method="post">
            <input type="hidden" name="original_image_path" value="{{ filename }}">
            <button type="submit" class="button">Draw</button>
        </form>
    </div>
    {% endif %}
</body>
</html>

"""

with open("templates/index_2.html", "w") as file:
    file.write(html_code)

print("HTML file created successfully!")
# Out:
# HTML file created successfully!

# %%
html_code = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Draw Result</title>
    <style>
        .container {
            display: flex;
            justify-content: space-between;
        }
        .image-container {
            width: 45%;
        }
        .image-container img {
            width: 100%;
        }
        .button-container {
            background-color: #4169E1;
            color: white;
            border: none;
            padding: 10px 20px;
            cursor: pointer;
            margin-top: 10px;
        }
        .button { background-color: #4169E1; color: white; border: none; padding: 10px 20px; cursor: pointer; margin-top: 10px; }
    </style>
</head>
<body>
    <h1>Draw Result</h1>
    <div class="container">
        <div class="image-container">
            <h2>Image with Rectangles</h2>
            <img src="{{ drawn_image_path }}" alt="Image with Rectangles">
        </div>
        <div class="image-container">
            <h2>Original Image</h2>
            <img src="{{ original_image_path }}" alt="Original Image">
        </div>
    </div>
    <div class="button-container">
        <form action="/" method="get">
            <button type="submit" class ="button">Exit</button>
        </form>
    </div>
</body>
</html>

"""

# Save the HTML file in Google Colab
with open("templates/result.html", "w") as file:
    file.write(html_code)

# %%
html_code = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Draw Result</title>
    <style>
        .container {
            display: flex;
            justify-content: space-between;
        }
        .image-container {
            width: 45%;
        }
        .image-container img {
            width: 100%;
        }
        .button-container {
            background-color: #4169E1;
            color: white;
            border: none;
            padding: 10px 20px;
            cursor: pointer;
            margin-top: 10px;
        }
        /*image styling */
        .gallery-container img {
            height: auto;
            max-width: 100%;
            display: block;
            margin: 10px;
            border: 1px solid black;
            transition: transform 0.5s ease-in-out;
        }
        /*scroll */
        .gallery-container  {
            max-width: fit-content;
            height: 400px;
            margin: auto;
            overflow-x: hidden;
            overflow-y: auto;
            white-space: nowrap;
            border: 1px solid black;
            padding: 10px;
            border-radius: 10px;
            background-color: #f4f4f4;
        }
        .gallery-container img:hover {
            transform: scale(1.1);
        }
        .button { background-color: #4169E1; color: white; border: none; padding: 10px 20px; cursor: pointer; margin-top: 10px; }
    </style>
</head>
<body>
    <h1>Draw Result</h1>
    <div class="container">
        <div class="image-container">
            <h2>Original Image</h2>
            <img src="{{ original_image_path }}" alt="Original Image">
        </div>
        <div class="image-container">
            <h2>Detected table</h2>
            <img src="{{ drawn_image_path }}" alt="Image with table detected">
        </div>
    </div>
    <h2>Detected Table</h2>
    <div class="container">
      <div class = "gallery-container">
          {% for image in images %}
              <img src="{{ url_for('static', filename='table_images/' ~ image) }}"  alt="Detail Table">
          {% endfor %}
      </div>
      <div class = "gallery-container">
        {% for table_html in tables %}
          <div style="text-align: center;">
            {{ table_html|safe }}
          </div>
        {% endfor %}
      </div>
    </div>
    <div class="button-container">
        <form action="/" method="get">
            <button type="submit" class ="button">Exit</button>
        </form>
    </div>
</body>
</html>

"""

# Save the HTML file in Google Colab
with open("templates/result.html", "w") as file:
    file.write(html_code)

print("HTML file created successfully!")
# Out:
# HTML file created successfully!

# %% [markdown]
# # html lib

# %%
# !sudo apt install tesseract-ocr -y
# !sudo apt install tesseract-ocr-vie -y  # Gói ngôn ngữ tiếng Việt
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr-vie is already the newest version (1:4.00~git30-7274cfa-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# ...

# %%
def is_integer(var):
  return isinstance(var, int)

# %%
def workbook_to_html(wb, sheet_name=0):
    ws = wb[wb.sheetnames[sheet_name]] if isinstance(sheet_name, int) else wb[sheet_name]
    merged_cells = ws.merged_cells.ranges  # Get merged cell ranges

    html = '<table border="1">\n'
    for i, row in enumerate(ws.iter_rows(values_only=True)):
        html += "  <tr>\n"
        for j, cell in enumerate(row):
            rowspan, colspan = 1, 1
            for merged in merged_cells:
                if ws.cell(row=i+1, column=j+1).coordinate in merged:
                    rowspan = merged.size["rows"]
                    colspan = merged.size["columns"]
                    if i+1 != merged.min_row or j+1 != merged.min_col:
                        cell = None  # Skip duplicate merged cells

            if cell is not None:
                attributes = ""
                if rowspan > 1:
                    attributes += f' rowspan="{rowspan}"'
                if colspan > 1:
                    attributes += f' colspan="{colspan}"'
                html += f'    <td{attributes}>{cell}</td>\n'

        html += "  </tr>\n"
    html += "</table>"

    return html

# %%
from openpyxl.styles import Alignment

# %%
import  pytesseract
def get_table_dict_content(image_test , table_dict):
  final_table_dict  = []
  h_original , w_original, c = np.array(image_test).shape
  for cell in table_dict:
    cell_dict = dict()
    bbox = cell['bbox']
    x1_512 , y1_512 , x2_512, y2_512 = bbox
    x1_ori = int(x1_512/512 * w_original)
    y1_ori = int(y1_512/768 * h_original)
    x2_ori = int(x2_512/512 * w_original)
    y2_ori = int(y2_512/768 * h_original)
    row_cnt = cell['row']
    col_cnt = cell['col']
    content = ''
    cell_dict['row'] = row_cnt
    cell_dict['col'] = col_cnt
    cell_dict['bbox'] = [x1_ori, y1_ori, x2_ori, y2_ori]
    final_table_dict.append(cell_dict)
  table_image_original = image_test.copy()
  final_table_dict_2 = []
  for cell in final_table_dict:
      cell_dict = dict()
      bbox = cell['bbox']
      x1, y1, x2, y2 = bbox
      row_cnt = cell['row']
      col_cnt = cell['col']
      content = ''
      cell_dict['row'] = row_cnt
      cell_dict['col'] = col_cnt
      # print(f' num :{row_cnt},  {col_cnt}')
      # cell_dict['bbox'] = [x1, y1, x2, y2]
      xmin = x1 -2
      if xmin < 0 :
        xmin = 0
      xmax = x2 + 2
      if xmax > w_original:
        xmax = w_original
      ymin = y1 -2
      if ymin < 0 :
        ymin = 0
      ymax = y2 + 2
      if ymax > h_original:
        ymax = h_original
      sub_image = table_image_original[ymin:ymax, xmin:xmax]

      scale_factor = 4  # Adjust as needed
      resized_image = cv2.resize(sub_image, (sub_image.shape[1] * scale_factor, sub_image.shape[0] * scale_factor), interpolation=cv2.INTER_CUBIC)
      text = pytesseract.image_to_string(resized_image, lang='vie')
      try:
        content = str(text)
      except:
        content = ' '
      cell_dict['content'] = content
      final_table_dict_2.append(cell_dict)
  return final_table_dict_2
def get_html_from_wb(final_table_dict_2, num_row, num_col):
  row_max = num_row
  col_max = num_col
  # print(row_max, col_max)
  wb = openpyxl.Workbook()
  sheet = wb.active
  for data_cell in final_table_dict_2:
    row_cnt = data_cell['row']
    col_cnt = data_cell['col']
    try:
      start_row = int(data_cell['row']) + 1
    except:
      start_row = int(data_cell['row'][0]) + 1
    try:
      start_col = int(data_cell['col']) + 1
    except:
      start_col = int(data_cell['col'][0]) + 1
    content = data_cell['content']
    if not content:
      content = ' '
    content = "".join(c for c in content if c.isprintable()) # keep only printable characters
    sheet.cell(row=start_row, column=start_col, value=content)
    sheet.cell(row=start_row, column=start_col).alignment = Alignment(horizontal='center', vertical='center')
  # merge cell
  for data_cell in final_table_dict_2:
    # check spanning cell
    row_merge_flag = 0
    col_merge_flag = 0
    row_cnt = data_cell['row']
    col_cnt = data_cell['col']
    # print(row_cnt)
    # print(col_cnt)
    if not is_integer(row_cnt):
      row_merge_flag = 1
    if not is_integer(col_cnt):
      col_merge_flag = 1
    if col_merge_flag == 1 and row_merge_flag == 0:
      start_col = int(data_cell['col'][0]) + 1
      end_col = int(data_cell['col'][-1]) + 1
      start_row = int(data_cell['row']) + 1
      end_row = int(data_cell['row']) + 1
      sheet.merge_cells(start_row=start_row, start_column=start_col, end_row=end_row, end_column=end_col)
    if col_merge_flag == 0 and row_merge_flag == 1:
      start_col = int(data_cell['col']) + 1
      end_col = int(data_cell['col']) + 1
      start_row = int(data_cell['row'][0]) + 1
      end_row = int(data_cell['row'][-1]) + 1
      sheet.merge_cells(start_row=start_row, start_column=start_col, end_row=end_row, end_column=end_col)
    if col_merge_flag == 1 and row_merge_flag == 1:
      start_col = int(data_cell['col'][0]) + 1
      end_col = int(data_cell['col'][-1]) + 1
      start_row = int(data_cell['row'][0]) + 1
      end_row = int(data_cell['row'][-1]) + 1
      sheet.merge_cells(start_row=start_row, start_column=start_col, end_row=end_row, end_column=end_col)
  # wb.save('test.xlsx')
  html_final = workbook_to_html(wb)
  return html_final

# %% [markdown]
# # code

# %%
# !pip install jdeskew

# %%
# !pip install ultralytics

# %%
import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")  # set device to gpu or cpu
device
# Out:
# device(type='cuda', index=0)

# %%
# !pip install flask==1.1.4
# !pip install Jinja2==3.1.2

# %%
import numpy as np
import torch
from flask import Flask, render_template, request, redirect
import os
import cv2
import split_model_lib
import merge_model_lib
import split_model_Unet_lib
from ultralytics import YOLO
from jdeskew.estimator import get_angle
from jdeskew.utility import rotate
import openpyxl
import pandas as pd
from openpyxl import load_workbook
H_SHAPE = 768
W_SHAPE = 512

# %%
def split_processing(image):
    image_test = np.array(image).astype(np.uint8)
    h_original , w_original, c = np.array(image_test).shape
    if (h_original > 512):
        threshold_heatmap_row = 0.5
    else :
        threshold_heatmap_row = 0.2
    if (w_original > 400):
        threshold_heatmap_col = 0.3
    else:
        threshold_heatmap_col = 0.2

    if h_original < 100:
        threshold_contour_row = 10
    elif h_original > 512:
        threshold_contour_row = 5
    else:
        threshold_contour_row = 10
    if w_original> 100:
        threshold_contour_col = 10
    else :
        threshold_contour_col = 10
    image = np.array(image_test)
    image_input = cv2.resize(image, (W_SHAPE, H_SHAPE))
    image_input = image_input.astype('float')
    image_input = np.array(image_input,dtype= np.float32)/255.0
    image_tensor =  torch.from_numpy(image_input)
    image_tensor = image_tensor.permute(2,0,1)
    image_tensor = torch.unsqueeze(image_tensor, dim = 0)
    image_tensor.shape
    a,b = split_task(image_tensor.to(device))
    row_list_ = split_model_lib.get_row_pred_line(a , threshold_heatmap_row, threshold_contour_row)
    row_list_ = sorted(row_list_)
    row_list_.insert(0, 1)
    row_list_.append(H_SHAPE-1)
    col_list_ = split_model_lib.get_col_pred_line(b, threshold_heatmap_col, threshold_contour_col)
    # print(row_list_)
    col_list_ = sorted(col_list_)
    col_list_.insert(0, 1)
    col_list_.append(W_SHAPE-1)  # add last column
    split_image = split_model_lib.show_line_pred(row_list_, col_list_, image)
    return split_image , row_list_, col_list_

def merge_processing(image , row_list_, col_list_):
    image_test = np.array(image).astype(np.uint8)  # convert to uint8 type
    h_original, w_original, c = np.array(image_test).shape
    image = np.array(image_test)
    image_input = cv2.resize(image, (W_SHAPE, H_SHAPE))
    image_input = image_input.astype('float')
    image_input = np.array(image_input,dtype= np.float32)/255.0
    image_tensor =  torch.from_numpy(image_input)
    image_tensor = image_tensor.permute(2,0,1)
    image_tensor = torch.unsqueeze(image_tensor, dim = 0)

    cell_bbox_ = merge_model_lib.get_pred_bbox_list(row_list_ , col_list_)
    bbox_input =  torch.from_numpy(np.array([cell_bbox_]))
    row_pred, col_pred = merge_task(image_tensor.to(device), bbox_input.to(device))
    last_cell = bbox_input.numpy()[-1]
    num_row, num_col =  last_cell[-1][0] , last_cell[-1][1]
    row_merge , col_merge  = merge_model_lib.get_final_pred_merge(row_pred, col_pred, num_row, num_col)
    table_dict  = merge_model_lib.get_table(row_merge, col_merge, np.array(cell_bbox_) )

    image_final = merge_model_lib.show_final_result_v2(image , table_dict , h_original, w_original)
    return image_final, table_dict , row_merge , col_merge

# %%
from pyngrok import ngrok
from IPython.core.display import display, HTML

# %%
# prompt: access google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # test

# %%
import numpy as np

import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd

# %%
model_folder_path = "/content/drive/MyDrive/model"
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")  # set device to gpu or cpu
model_split = "/content/drive/MyDrive/model/split/split_unet_model_real_data.pth"
model_merge =  "/content/drive/MyDrive/model/merge/merge_model_fintab_read_data_epoch_24_0406.pth"
model_TD =  YOLO(model_folder_path + '/best_2.pt')

try:
    split_task = split_model_Unet_lib.init_model()  # Load the pre-trained model from the saved weights
    split_task.to(device)
    weights = torch.load(model_split)
    split_task.load_state_dict(weights)
    print("app.py: Model split loaded successfully.")
except:
    print("app.py: Error loading the model split.")
    exit()

try:
    merge_task = merge_model_lib.init_merge_model()  # Load the pre-trained model from the saved weights
    merge_task.to(device)
    weights = torch.load(model_merge)
    merge_task.load_state_dict(weights)
    print("app.py: Model merge loaded successfully.")
except:
    print("app.py: Error loading the model merge.")
    exit()
# Out:
# app.py: Model split loaded successfully.
# app.py: Model merge loaded successfully.

# %%
h_stand = 842
w_stand = 596

# %%
def get_table_dict_high_res(table_dict_768_512, h_table_high_res, w_table_high_res):
  table_dict_high_res =[]
  for cell in table_dict_768_512:
    cell_dict = dict()
    bbox = cell['bbox']
    x1_768_512 , y1_768_512 , x2_768_512, y2_768_512 = bbox
    x1_high_res = int(x1_768_512/512 * w_table_high_res)
    y1_high_res = int(y1_768_512/768 * h_table_high_res)
    x2_high_res = int(x2_768_512/512 * w_table_high_res)
    y2_high_res = int(y2_768_512/768 * h_table_high_res)
    cell_dict['row'] = cell['row']
    cell_dict['col'] = cell['col']
    cell_dict['bbox'] = [x1_high_res, y1_high_res, x2_high_res, y2_high_res]
    cell_dict['content'] = cell['content']
    table_dict_high_res.append(cell_dict)
  return table_dict_high_res

def show_result(table_image, table_dict):
  table_image_draw = table_image.copy()
  for cell in table_dict:
    bbox = cell['bbox']
    x1, y1, x2, y2 = bbox
    cv2.rectangle(table_image_draw, (x1, y1), (x2, y2), (255, 0, 0), 2)
  return table_image_draw
def get_table_dict_content_v2(table_image, table_dict):
  final_table_dict_2 =[]
  table_image_np = np.array(table_image)
  h_original , w_original, c = np.array(table_image).shape
  for cell in table_dict:
      cell_dict = dict()
      bbox = cell['bbox']
      x1, y1, x2, y2 = bbox
      row_cnt = cell['row']
      col_cnt = cell['col']
      content = ''
      cell_dict['row'] = row_cnt
      cell_dict['col'] = col_cnt
      # print(f' num :{row_cnt},  {col_cnt}')
      # cell_dict['bbox'] = [x1, y1, x2, y2]
      xmin = x1 -2
      if xmin < 0 :
        xmin = 0
      xmax = x2 + 2
      if xmax > w_original:
        xmax = w_original
      ymin = y1 -2
      if ymin < 0 :
        ymin = 0
      ymax = y2 + 2
      if ymax > h_original:
        ymax = h_original
      sub_image = table_image_np[ymin:ymax, xmin:xmax]

      scale_factor = 4  # Adjust as needed
      resized_image = cv2.resize(sub_image, (sub_image.shape[1] * scale_factor, sub_image.shape[0] * scale_factor), interpolation=cv2.INTER_CUBIC)
      text = pytesseract.image_to_string(resized_image, lang='vie')
      try:
        content = str(text)
      except:
        content = ' '
      cell_dict['content'] = content
      final_table_dict_2.append(cell_dict)
  return final_table_dict_2

def get_html_from_wb(final_table_dict_2, num_row, num_col):
  row_max = num_row
  col_max = num_col
  # print(row_max, col_max)
  wb = openpyxl.Workbook()
  sheet = wb.active
  for data_cell in final_table_dict_2:
    row_cnt = data_cell['row']
    col_cnt = data_cell['col']
    try:
      start_row = int(data_cell['row']) + 1
    except:
      start_row = int(data_cell['row'][0]) + 1
    try:
      start_col = int(data_cell['col']) + 1
    except:
      start_col = int(data_cell['col'][0]) + 1
    content = data_cell['content']
    if not content:
      content = ' '
    content = "".join(c for c in content if c.isprintable()) # keep only printable characters
    sheet.cell(row=start_row, column=start_col, value=content)
    sheet.cell(row=start_row, column=start_col).alignment = Alignment(horizontal='center', vertical='center')
  # merge cell
  for data_cell in final_table_dict_2:
    # check spanning cell
    row_merge_flag = 0
    col_merge_flag = 0
    row_cnt = data_cell['row']
    col_cnt = data_cell['col']
    # print(row_cnt)
    # print(col_cnt)
    if not is_integer(row_cnt):
      row_merge_flag = 1
    if not is_integer(col_cnt):
      col_merge_flag = 1
    if col_merge_flag == 1 and row_merge_flag == 0:
      start_col = int(data_cell['col'][0]) + 1
      end_col = int(data_cell['col'][-1]) + 1
      start_row = int(data_cell['row']) + 1
      end_row = int(data_cell['row']) + 1
      sheet.merge_cells(start_row=start_row, start_column=start_col, end_row=end_row, end_column=end_col)
    if col_merge_flag == 0 and row_merge_flag == 1:
      start_col = int(data_cell['col']) + 1
      end_col = int(data_cell['col']) + 1
      start_row = int(data_cell['row'][0]) + 1
      end_row = int(data_cell['row'][-1]) + 1
      sheet.merge_cells(start_row=start_row, start_column=start_col, end_row=end_row, end_column=end_col)
    if col_merge_flag == 1 and row_merge_flag == 1:
      start_col = int(data_cell['col'][0]) + 1
      end_col = int(data_cell['col'][-1]) + 1
      start_row = int(data_cell['row'][0]) + 1
      end_row = int(data_cell['row'][-1]) + 1
      sheet.merge_cells(start_row=start_row, start_column=start_col, end_row=end_row, end_column=end_col)
  # wb.save('test.xlsx')
  html_final = workbook_to_html(wb)
  return html_final

# %%
page_image_high_res = Image.open('/content/demo_file/page_17.png')
plt.imshow(page_image_high_res)

(h_page_high_res, w_page_high_res) = np.array(page_image_high_res).shape[:2]
print(f'h_high_res: {h_page_high_res}, w_high_res: {w_page_high_res}')
scale_rate_h =  h_stand/h_page_high_res
scale_rate_w =  w_stand/w_page_high_res
if scale_rate_h < 1 and scale_rate_w < 1:
  if scale_rate_h > scale_rate_w:
    h_page_original = int(h_page_high_res*scale_rate_h)
    w_page_original = int(w_page_high_res*scale_rate_h)
  else:
    h_page_original = int(h_page_high_res*scale_rate_w)
    w_page_original = int(w_page_high_res*scale_rate_w)
else :
  h_page_original = h_page_high_res
  w_page_original = w_page_high_res
print(f'h_original: {h_page_original}, w_original: {w_page_original}')
original_image = cv2.resize(np.array(page_image_high_res), (w_page_original, h_page_original))

angle = get_angle(np.array(original_image))
center = (w_page_original // 2, h_page_original // 2)
M = cv2.getRotationMatrix2D(center, angle, 1.0)
page_image = cv2.warpAffine(original_image, M, (w_page_original, h_page_original),flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
print(f'angle :{angle}')
# Out:
# h_high_res: 3510, w_high_res: 2481
# h_original: 843, w_original: 596
# angle :0.6761268781302173

# %%
import  pytesseract

# %%
from IPython.display import HTML

# %%
### TD
TD_reseults = model_TD(page_image , conf=0.7)
TD_bbox = TD_reseults[0].boxes.xyxy.cpu().numpy()
bbox = TD_bbox[1]
x1, y1, x2, y2 = int(bbox[0]), int(bbox[1]), int(bbox[2]), int(bbox[3])
table_image = page_image[y1:y2, x1:x2]
h_original_table, w_original_table, _ = table_image.shape
split_image , row_list_, col_list_ = split_processing(table_image)
table_image_final, table_dict_768_512 , row_merge , col_merge  = merge_processing(table_image, row_list_, col_list_)


# table_image_high_res
x1_table_high_res = int(x1/w_page_original*w_page_high_res)
y1_table_high_res = int(y1/h_page_original*h_page_high_res)
x2_table_high_res = int(x2/w_page_original*w_page_high_res)
y2_table_high_res = int(y2/h_page_original*h_page_high_res)
page_image_high_res_np = np.array(page_image_high_res)
table_image_high_res = page_image_high_res_np[y1_table_high_res:y2_table_high_res, x1_table_high_res:x2_table_high_res]
table_dict_high_res = get_table_dict_high_res(table_dict_768_512, table_image_high_res.shape[0], table_image_high_res.shape[1])

result = show_result(table_image_high_res, table_dict_high_res)
plt.imshow(result)


num_row, num_col = row_merge.shape
table_dict_content = get_table_dict_content_v2(table_image_high_res , table_dict_high_res)
html_pred = get_html_from_wb(table_dict_content, num_row, num_col)

display(HTML(html_pred))
# Out:
# 0: 640x480 2 tables, 22.5ms
# Speed: 3.7ms preprocess, 22.5ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 480)
# /content/merge_model_lib.py:195: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   rois_1 = torch.tensor(rois[0])
# <table border="1">
#   <tr>
#     <td rowspan="2">¬⁄</td>
#     <td>Công cụ dụngcụ</td>
#     <td>Chỉ phí sửa chữavăn phòng và nhàxưởng</td>
#     <td>Khác</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>VND</td>
#     <td></td>
#     <td>VND</td>
#     <td>VND</td>
#   </tr>
#   <tr>
#     <td>Số dư tại ngày 01/01/2025</td>
#     <td>958.597.413</td>
#     <td>2.217.330.843</td>
#     <td>238.670.113</td>
#     <td>3.444.798.369</td>
#   </tr>
#   <tr>
#     <td>Tăng trong kỳ</td>
#     <td>I 18.640.000</td>
#     <td></td>
#     <td>48.000.000</td>
#     <td>166.640.000</td>
#   </tr>
# ...

# %% [markdown]
# # final

# %%
# app = Flask(__name__)

# model_folder_path = "/content/drive/MyDrive/model"
# UPLOAD_FOLDER = 'static/uploads'
# RESULT_FOLDER = 'static/results'
# TABLEIMAGE_FOLDER = 'static/table_images'
# os.makedirs(UPLOAD_FOLDER, exist_ok=True)
# os.makedirs(RESULT_FOLDER, exist_ok=True)
# os.makedirs(TABLEIMAGE_FOLDER,exist_ok=True)
# # clear all file inside the TABLEIMAGE_FOLDER
# for f in os.listdir(TABLEIMAGE_FOLDER):
#     if os.path.isfile(os.path.join(TABLEIMAGE_FOLDER, f)):
#         os.remove(os.path.join(TABLEIMAGE_FOLDER, f))

# RESULT_IMAGE_NAME = "processed_image.jpg"
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")  # set device to gpu or cpu
# model_split = "/content/drive/MyDrive/model/split/split_unet_model_real_data.pth"
# model_merge =  "/content/drive/MyDrive/model/merge/merge_model_fintab_read_data_epoch_24_0406.pth"
# model_TD =  YOLO(model_folder_path + '/best_2.pt')
# try:
#     split_task = split_model_Unet_lib.init_model()  # Load the pre-trained model from the saved weights
#     split_task.to(device)
#     weights = torch.load(model_folder_path + model_split)
#     split_task.load_state_dict(weights)
#     print("app.py: Model split loaded successfully.")
# except:
#     print("app.py: Error loading the model split.")
#     exit()

# try:
#     merge_task = merge_model_lib.init_merge_model()  # Load the pre-trained model from the saved weights
#     merge_task.to(device)
#     weights = torch.load(model_folder_path + model_merge)
#     merge_task.load_state_dict(weights)
#     print("app.py: Model merge loaded successfully.")
# except:
#     print("app.py: Error loading the model merge.")
#     exit()


# @app.route("/", methods=["GET", "POST"])
# def upload_file():
#     for f in os.listdir(TABLEIMAGE_FOLDER):
#         if os.path.isfile(os.path.join(TABLEIMAGE_FOLDER, f)):
#             os.remove(os.path.join(TABLEIMAGE_FOLDER, f))
#     if request.method == "POST":
#         if "file" not in request.files:
#             return "No file part"
#         file = request.files["file"]
#         if file.filename == "":
#             return "No selected file"
#         if file:
#             file_path = os.path.join(UPLOAD_FOLDER, RESULT_IMAGE_NAME)
#             file.save(file_path)
#             return render_template("index_2.html", filename= RESULT_IMAGE_NAME, original_image_path=RESULT_IMAGE_NAME)
#     return render_template("index_2.html", filename=None)

# @app.route("/draw", methods=["POST"])
# def draw_rectangles():
#     html_pred_list = []
#     original_image_path = request.form["original_image_path"]
#     input_path = os.path.join(UPLOAD_FOLDER, original_image_path)
#     output_path = os.path.join(RESULT_FOLDER, "processed_" + original_image_path)
#     if not os.path.exists(input_path):
#         return "No uploaded image found!"
#     original_image = cv2.imread(input_path)
#     (h, w) = original_image.shape[:2]
#     angle = get_angle(np.array(original_image))
#     center = (w // 2, h // 2)
#     M = cv2.getRotationMatrix2D(center, angle, 1.0)
#     image = cv2.warpAffine(original_image, M, (w, h),flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
#     height, width, _ = image.shape

#     TD_reseults = model_TD(image)
#     TD_bbox = TD_reseults[0].boxes.xyxy.cpu().numpy()
#     for bbox in TD_bbox:
#         x1, y1, x2, y2 = int(bbox[0]), int(bbox[1]), int(bbox[2]), int(bbox[3])
#         cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
#     cv2.imwrite(output_path, image)
#     # save the table images
#     for i, bbox in enumerate(TD_bbox):
#         x1, y1, x2, y2 = int(bbox[0]), int(bbox[1]), int(bbox[2]), int(bbox[3])
#         table_image = image[y1:y2, x1:x2]
#         h_original, w_original, _ = table_image.shape
#         split_image , row_list_, col_list_ = split_processing(table_image)  # process each table image using the split model
#         table_image_final, table_dict , row_merge , col_merge  = merge_processing(table_image, row_list_, col_list_)  # process each table image using the merge model

#         num_row, num_col = row_merge.shape
#         table_dict_content = get_table_dict_content(table_image , table_dict)
#         html_pred = get_html_from_wb(table_dict_content, num_row, num_col)
#         html_pred_list.append(html_pred)
#         display(HTML(html_pred))

#         table_image_path = os.path.join(TABLEIMAGE_FOLDER, f"table_{i+1}.jpg")
#         cv2.imwrite(table_image_path, table_image_final)
#     image_files = [f for f in os.listdir(TABLEIMAGE_FOLDER) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]
#     print(image_files)


#     return render_template("result.html",  original_image_path=input_path, drawn_image_path=output_path , images=image_files ,tables=html_pred_list)

# ngrok.set_auth_token("2twjd9sklgZgSMOE1YPBHhsxnrt_7KVCv2fdqHNd2kWw5AHx7")
# # Start ngrok to expose the app
# public_url = ngrok.connect(5000)
# print("Public URL:", public_url)

# # Run Flask app
# app.run(port=5000)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# app.py: Error loading the model split.
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:385: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# app.py: Error loading the model merge.
# Public URL: NgrokTunnel: "https://ab55-34-16-136-35.ngrok-free.app" -> "http://localhost:5000"
# ...

# %% [markdown]
# # final 2

# %%
def get_table_dict_high_res(table_dict_768_512, h_table_high_res, w_table_high_res):
  table_dict_high_res =[]
  for cell in table_dict_768_512:
    cell_dict = dict()
    bbox = cell['bbox']
    x1_768_512 , y1_768_512 , x2_768_512, y2_768_512 = bbox
    x1_high_res = int(x1_768_512/512 * w_table_high_res)
    y1_high_res = int(y1_768_512/768 * h_table_high_res)
    x2_high_res = int(x2_768_512/512 * w_table_high_res)
    y2_high_res = int(y2_768_512/768 * h_table_high_res)
    cell_dict['row'] = cell['row']
    cell_dict['col'] = cell['col']
    cell_dict['bbox'] = [x1_high_res, y1_high_res, x2_high_res, y2_high_res]
    cell_dict['content'] = cell['content']
    table_dict_high_res.append(cell_dict)
  return table_dict_high_res

def show_result(table_image, table_dict):
  table_image_draw = table_image.copy()
  for cell in table_dict:
    bbox = cell['bbox']
    x1, y1, x2, y2 = bbox
    cv2.rectangle(table_image_draw, (x1, y1), (x2, y2), (255, 0, 0), 2)
  return table_image_draw
def get_table_dict_content_v2(table_image, table_dict):
  final_table_dict_2 =[]
  table_image_np = np.array(table_image)
  h_original , w_original, c = np.array(table_image).shape
  for cell in table_dict:
      cell_dict = dict()
      bbox = cell['bbox']
      x1, y1, x2, y2 = bbox
      row_cnt = cell['row']
      col_cnt = cell['col']
      content = ''
      cell_dict['row'] = row_cnt
      cell_dict['col'] = col_cnt
      # print(f' num :{row_cnt},  {col_cnt}')
      # cell_dict['bbox'] = [x1, y1, x2, y2]
      xmin = x1 -2
      if xmin < 0 :
        xmin = 0
      xmax = x2 + 2
      if xmax > w_original:
        xmax = w_original
      ymin = y1 -2
      if ymin < 0 :
        ymin = 0
      ymax = y2 + 2
      if ymax > h_original:
        ymax = h_original
      sub_image = table_image_np[ymin:ymax, xmin:xmax]

      scale_factor = 4  # Adjust as needed
      resized_image = cv2.resize(sub_image, (sub_image.shape[1] * scale_factor, sub_image.shape[0] * scale_factor), interpolation=cv2.INTER_CUBIC)
      text = pytesseract.image_to_string(resized_image, lang='vie')
      try:
        content = str(text)
      except:
        content = ' '
      cell_dict['content'] = content
      final_table_dict_2.append(cell_dict)
  return final_table_dict_2

def get_html_from_wb(final_table_dict_2, num_row, num_col):
  row_max = num_row
  col_max = num_col
  # print(row_max, col_max)
  wb = openpyxl.Workbook()
  sheet = wb.active
  for data_cell in final_table_dict_2:
    row_cnt = data_cell['row']
    col_cnt = data_cell['col']
    try:
      start_row = int(data_cell['row']) + 1
    except:
      start_row = int(data_cell['row'][0]) + 1
    try:
      start_col = int(data_cell['col']) + 1
    except:
      start_col = int(data_cell['col'][0]) + 1
    content = data_cell['content']
    if not content:
      content = ' '
    content = "".join(c for c in content if c.isprintable()) # keep only printable characters
    sheet.cell(row=start_row, column=start_col, value=content)
    sheet.cell(row=start_row, column=start_col).alignment = Alignment(horizontal='center', vertical='center')
  # merge cell
  for data_cell in final_table_dict_2:
    # check spanning cell
    row_merge_flag = 0
    col_merge_flag = 0
    row_cnt = data_cell['row']
    col_cnt = data_cell['col']
    # print(row_cnt)
    # print(col_cnt)
    if not is_integer(row_cnt):
      row_merge_flag = 1
    if not is_integer(col_cnt):
      col_merge_flag = 1
    if col_merge_flag == 1 and row_merge_flag == 0:
      start_col = int(data_cell['col'][0]) + 1
      end_col = int(data_cell['col'][-1]) + 1
      start_row = int(data_cell['row']) + 1
      end_row = int(data_cell['row']) + 1
      sheet.merge_cells(start_row=start_row, start_column=start_col, end_row=end_row, end_column=end_col)
    if col_merge_flag == 0 and row_merge_flag == 1:
      start_col = int(data_cell['col']) + 1
      end_col = int(data_cell['col']) + 1
      start_row = int(data_cell['row'][0]) + 1
      end_row = int(data_cell['row'][-1]) + 1
      sheet.merge_cells(start_row=start_row, start_column=start_col, end_row=end_row, end_column=end_col)
    if col_merge_flag == 1 and row_merge_flag == 1:
      start_col = int(data_cell['col'][0]) + 1
      end_col = int(data_cell['col'][-1]) + 1
      start_row = int(data_cell['row'][0]) + 1
      end_row = int(data_cell['row'][-1]) + 1
      sheet.merge_cells(start_row=start_row, start_column=start_col, end_row=end_row, end_column=end_col)
  # wb.save('test.xlsx')
  html_final = workbook_to_html(wb)
  return html_final

# %%
import numpy as np
import torch
from flask import Flask, render_template, request, redirect
import os
import cv2
import split_model_lib
import merge_model_lib
import split_model_Unet_lib
from ultralytics import YOLO
from jdeskew.estimator import get_angle
from jdeskew.utility import rotate
import openpyxl
import pandas as pd
from openpyxl import load_workbook
from pyngrok import ngrok
from IPython.core.display import display, HTML
import  pytesseract
from IPython.display import HTML
from openpyxl.styles import Alignment
H_SHAPE = 768
W_SHAPE = 512

# %%
app = Flask(__name__)

model_folder_path = "/content/drive/MyDrive/model"
UPLOAD_FOLDER = 'static/uploads'
RESULT_FOLDER = 'static/results'
TABLEIMAGE_FOLDER = 'static/table_images'
os.makedirs(UPLOAD_FOLDER, exist_ok=True)
os.makedirs(RESULT_FOLDER, exist_ok=True)
os.makedirs(TABLEIMAGE_FOLDER,exist_ok=True)
h_stand = 842
w_stand = 596
# clear all file inside the TABLEIMAGE_FOLDER
for f in os.listdir(TABLEIMAGE_FOLDER):
    if os.path.isfile(os.path.join(TABLEIMAGE_FOLDER, f)):
        os.remove(os.path.join(TABLEIMAGE_FOLDER, f))

RESULT_IMAGE_NAME = "processed_image.jpg"
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")  # set device to gpu or cpu
model_split = "/content/drive/MyDrive/model/split/split_unet_model_real_data.pth"
model_merge =  "/content/drive/MyDrive/model/merge/merge_model_fintab_read_data_epoch_24_0406.pth"
model_TD =  YOLO(model_folder_path + '/best_2.pt')
try:
    split_task = split_model_Unet_lib.init_model()  # Load the pre-trained model from the saved weights
    split_task.to(device)
    weights = torch.load(model_split)
    split_task.load_state_dict(weights)
    print("app.py: Model split loaded successfully.")
except:
    print("app.py: Error loading the model split.")
    exit()

try:
    merge_task = merge_model_lib.init_merge_model()  # Load the pre-trained model from the saved weights
    merge_task.to(device)
    weights = torch.load(model_merge)
    merge_task.load_state_dict(weights)
    print("app.py: Model merge loaded successfully.")
except:
    print("app.py: Error loading the model merge.")
    exit()


@app.route("/", methods=["GET", "POST"])
def upload_file():
    for f in os.listdir(TABLEIMAGE_FOLDER):
        if os.path.isfile(os.path.join(TABLEIMAGE_FOLDER, f)):
            os.remove(os.path.join(TABLEIMAGE_FOLDER, f))
    if request.method == "POST":
        if "file" not in request.files:
            return "No file part"
        file = request.files["file"]
        if file.filename == "":
            return "No selected file"
        if file:
            file_path = os.path.join(UPLOAD_FOLDER, RESULT_IMAGE_NAME)
            file.save(file_path)
            return render_template("index_2.html", filename= RESULT_IMAGE_NAME, original_image_path=RESULT_IMAGE_NAME)
    return render_template("index_2.html", filename=None)

@app.route("/draw", methods=["POST"])
def draw_rectangles():
    html_pred_list = []
    original_image_path = request.form["original_image_path"]
    input_path = os.path.join(UPLOAD_FOLDER, original_image_path)
    output_path = os.path.join(RESULT_FOLDER, "processed_" + original_image_path)
    if not os.path.exists(input_path):
        return "No uploaded image found!"
    page_image_high_res = cv2.imread(input_path)
    (h_page_high_res, w_page_high_res) = np.array(page_image_high_res).shape[:2]
    print(f'h_high_res: {h_page_high_res}, w_high_res: {w_page_high_res}')
    scale_rate_h =  h_stand/h_page_high_res
    scale_rate_w =  w_stand/w_page_high_res
    if scale_rate_h < 1 and scale_rate_w < 1:
      if scale_rate_h > scale_rate_w:
        h_page_original = int(h_page_high_res*scale_rate_h)
        w_page_original = int(w_page_high_res*scale_rate_h)
      else:
        h_page_original = int(h_page_high_res*scale_rate_w)
        w_page_original = int(w_page_high_res*scale_rate_w)
    else :
      h_page_original = h_page_high_res
      w_page_original = w_page_high_res
    print(f'h_original: {h_page_original}, w_original: {w_page_original}')
    original_image = cv2.resize(np.array(page_image_high_res), (w_page_original, h_page_original))

    angle = get_angle(np.array(original_image))
    center = (w_page_original // 2, h_page_original // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    page_image = cv2.warpAffine(original_image, M, (w_page_original, h_page_original),flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    print(f'angle :{angle}')

    TD_reseults = model_TD(page_image)
    TD_bbox = TD_reseults[0].boxes.xyxy.cpu().numpy()

    ### get table bbox on high res ########
    page_image_high_res_np = np.array(page_image_high_res)
    for bbox in TD_bbox:
      x1 , y1 , x2 , y2 = int(bbox[0]), int(bbox[1]), int(bbox[2]), int(bbox[3])
      x1_table_high_res = int(x1/w_page_original*w_page_high_res)
      y1_table_high_res = int(y1/h_page_original*h_page_high_res)
      x2_table_high_res = int(x2/w_page_original*w_page_high_res)
      y2_table_high_res = int(y2/h_page_original*h_page_high_res)

    ######################################
    for bbox in TD_bbox:
        x1, y1, x2, y2 = int(bbox[0]), int(bbox[1]), int(bbox[2]), int(bbox[3])
        cv2.rectangle(page_image, (x1, y1), (x2, y2), (0, 255, 0), 2)
    cv2.imwrite(output_path, page_image)
    # save the table images

    for i, bbox in enumerate(TD_bbox):
        x1, y1, x2, y2 = int(bbox[0]), int(bbox[1]), int(bbox[2]), int(bbox[3])
        table_image = page_image[y1:y2, x1:x2]
        h_original, w_original, _ = table_image.shape
        split_image , row_list_, col_list_ = split_processing(table_image)  # process each table image using the split model
        table_image_final, table_dict_768_512 , row_merge , col_merge  = merge_processing(table_image, row_list_, col_list_)  # process each table image using the merge model


        x1 , y1 , x2 , y2 = int(bbox[0]), int(bbox[1]), int(bbox[2]), int(bbox[3])
        x1_table_high_res = int(x1/w_page_original*w_page_high_res)
        y1_table_high_res = int(y1/h_page_original*h_page_high_res)
        x2_table_high_res = int(x2/w_page_original*w_page_high_res)
        y2_table_high_res = int(y2/h_page_original*h_page_high_res)
        table_image_high_res = page_image_high_res_np[y1_table_high_res:y2_table_high_res, x1_table_high_res:x2_table_high_res]
        table_dict_high_res = get_table_dict_high_res(table_dict_768_512, table_image_high_res.shape[0], table_image_high_res.shape[1])

        num_row, num_col = row_merge.shape
        table_dict_content = get_table_dict_content_v2(table_image_high_res , table_dict_high_res)
        html_pred = get_html_from_wb(table_dict_content, num_row, num_col)
        html_pred_list.append(html_pred)
        display(HTML(html_pred))

        table_image_path = os.path.join(TABLEIMAGE_FOLDER, f"table_{i+1}.jpg")
        cv2.imwrite(table_image_path, table_image_final)
    image_files = [f for f in os.listdir(TABLEIMAGE_FOLDER) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]
    print(image_files)


    return render_template("result.html",  original_image_path=input_path, drawn_image_path=output_path , images=image_files ,tables=html_pred_list)

ngrok.set_auth_token("2twjd9sklgZgSMOE1YPBHhsxnrt_7KVCv2fdqHNd2kWw5AHx7")
# Start ngrok to expose the app
public_url = ngrok.connect(5000)
print("Public URL:", public_url)

# Run Flask app
app.run(port=5000)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# app.py: Model split loaded successfully.
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:385: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# app.py: Model merge loaded successfully.
# Public URL: NgrokTunnel: "https://a572-34-16-136-35.ngrok-free.app" -> "http://localhost:5000"
# ...
